# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import sys

from scipy.spatial import KDTree

# %% [markdown]
# # Load cleaned wildfire data

# %%
# Save space using smaller dtypes
fires = pd.read_csv("D:/wildfires/fires_cleaned.csv", index_col="FOD_ID", dtype={
    'FIRE_YEAR': np.int16,
    'DISCOVERY_DOY': np.int16
})
# Shrink memory use by using categoricals rather than strings, when appropriate
fires.STAT_CAUSE_DESCR = pd.Categorical(fires.STAT_CAUSE_DESCR)
fires.STATE = pd.Categorical(fires.STATE)
fires.DISCOVERY_MONTH = pd.Categorical(fires.DISCOVERY_MONTH)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
fires.sample(5)
# Out:
#           FIRE_NAME STAT_CAUSE_DESCR  FIRE_YEAR  DISCOVERY_DOY  FIRE_SIZE  \
# FOD_ID
# 201140120       NaN   Debris Burning       2011             80        0.1
# 986206          NaN   Debris Burning       2000             83        2.0
# 920086          NaN   Debris Burning       2005             89        6.0
# 184758        MNL11            Arson       1992             78        3.0
# 608944          NaN            Arson       2004             95        3.0
#
#             LATITUDE  LONGITUDE STATE  CONTAINED DISCOVERY_MONTH
# FOD_ID
# 201140120  41.092564 -95.976501    NE       True               3
# 986206     34.467200 -92.886400    AR      False               3
# 920086     34.794700 -88.632200    MS      False               3
# 184758     46.209100 -93.756400    MN       True               3
# 608944     35.628730 -94.811130    OK      False               4

# %% [markdown]
# # Load city-level data

# %%
cities = pd.read_csv("D:/wildfires/worldcitiespop.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Drop cities with unknown population
cities = cities[~pd.isna(cities.Population)]

# %%
# Only cities in North America, for speed
north_america = set(['us', 'ca', 'mx'])
cities = cities[cities.Country.apply(lambda x: x in north_america)]

# %%
cities.sample(5)
# Out:
#         Country          City    AccentCity Region  Population   Latitude  \
# 1879808      mx  huitziltepec  Huitziltepec     12      4419.0  17.816667
# 2924960      us      coventry      Coventry     CT     12428.0  41.770000
# 1861786      mx  buenos aires  Buenos Aires     16     10707.0  19.066667
# 1915250      mx       tocuila       Tocuila     30      4248.0  18.950000
# 1857343      mx    acuexcomac    Acuexcomac     21      4236.0  18.841667
#
#           Longitude
# 1879808  -99.466667
# 2924960  -72.305556
# 1861786 -102.166667
# 1915250  -97.016667
# 1857343  -98.063889

# %% [markdown]
# # Augment data to include population center distances

# %%
cities[['Latitude', 'Longitude']].shape
# Out:
# (6583, 2)

# %%
# Make KD-trees for fast lookup
for pop in 10**np.array([6,5,4,3]):
    
    print("Querying for cities with population >= %d" % pop)
    
    cities_pop = cities.loc[cities.Population >= pop]
    
    print("%d fires and %d cities" % (fires.shape[0], cities_pop.shape[0]))
    
    kd_tree = KDTree(cities_pop[['Latitude', 'Longitude']])
    # %time d_neighbors, idx_neighbors = kd_tree.query(fires[['LATITUDE', 'LONGITUDE']])
    
    # Store resulting distances
    fires["DISTANCE_CITY_%d" % pop] = d_neighbors
# Out:
# Querying for cities with population >= 1000000
# 1880465 fires and 21 cities
# Wall time: 2min 50s
# Querying for cities with population >= 100000
# 1880465 fires and 385 cities
# Wall time: 4min 3s
# Querying for cities with population >= 10000
# 1880465 fires and 4421 cities
# Wall time: 5min 23s
# Querying for cities with population >= 1000
# 1880465 fires and 6565 cities
# Wall time: 5min 53s

# %%
fires.sample(5)
# Out:
#                  FIRE_NAME STAT_CAUSE_DESCR  FIRE_YEAR  DISCOVERY_DOY  \
# FOD_ID
# 201151882    WEST BAY (03)        Lightning       2011            160
# 1091452                NaN         Railroad       1993             56
# 217647             HANCOCK    Equipment Use       1998            227
# 1671352                NaN   Debris Burning       2007            288
# 1643291    FY2000-POLK-133   Debris Burning       2000             63
#
#            FIRE_SIZE   LATITUDE   LONGITUDE STATE  CONTAINED DISCOVERY_MONTH  \
# FOD_ID
# 201151882       35.0  30.270400  -85.898300    FL       True               6
# 1091452         15.0  28.220000  -81.730000    FL      False               2
# 217647           1.0  38.832631 -120.867219    CA       True               8
# 1671352         35.0  38.444030  -83.218270    KY       True              10
# 1643291         25.1  33.933100  -85.291000    GA       True               3
#
#            DISTANCE_CITY_1000000  DISTANCE_CITY_100000  DISTANCE_CITY_10000  \
# FOD_ID
# 201151882               9.478344              1.626133             0.251226
# 1091452                13.444523              0.473338             0.154244
# 217647                  5.453439              0.427358             0.124302
# 1671352                 5.589353              1.301509             0.362425
# 1643291                 8.260883              0.921543             0.347594
#
#            DISTANCE_CITY_1000
# FOD_ID
# 201151882            0.251226
# 1091452              0.154244
# 217647               0.124302
# 1671352              0.362425
# 1643291              0.125773

# %% [markdown]
# # Load weather-station level data

# %%
stations = pd.read_csv('D:/wildfires/isd-history.csv')

# %%
# Only cities in North America, for speed. Also exclude unknown latitude, longitude, elevation
north_america = set(['US', 'CA', 'MX'])
stations = stations[stations.CTRY.apply(lambda x: x in north_america)
                & ~pd.isna(stations.LAT)
                & ~pd.isna(stations.LON)
                & ~pd.isna(stations["ELEV(M)"])]

# %%
stations.sample(5)
# Out:
#          USAF   WBAN                       STATION NAME CTRY STATE  ICAO  \
# 19507  724293    376                       MOUNT WERNER   US    CO  K3MW
# 17127  720202  99999                      TILLAMOOK AWS   US    OR  KTMK
# 17119  720172  99999                 MENA INTERMOUNTAIN   US    AR  KMEZ
# 17471  720542  99999  LARGO VISTA / RUSTY ALLEN AIRPORT   US    TX  KRYW
# 15303  702700  99999      FT. RICHARDSON/BRYANT AHP  AK   US   NaN  PAFR
#
#           LAT      LON  ELEV(M)     BEGIN       END
# 19507  40.460 -106.760   3241.2  20050322  20140721
# 17127  45.417 -123.817     11.0  20040429  20180514
# 17119  34.545  -94.203    329.0  20041103  20051231
# 17471  30.500  -97.967    375.0  20080825  20180322
# 15303  61.267 -149.650    115.0  19731201  20180520

# %% [markdown]
# # Augment data to include nearest elevation

# %%
# Make KD-trees for fast lookup
    
print("Querying for elevation")

print("%d fires and %d stations" % (fires.shape[0], stations.shape[0]))

kd_tree = KDTree(stations[['LAT', 'LON']])
# %time d_neighbors, idx_neighbors = kd_tree.query(fires[['LATITUDE', 'LONGITUDE']])

# Store resulting elevations
fires["APPROX_ELEVATION"] = stations["ELEV(M)"].iloc[idx_neighbors].values
# Out:
# Querying for elevation
# 1880465 fires and 9498 stations
# Wall time: 6min 18s

# %%
fires.sample(5)
# Out:
#               FIRE_NAME STAT_CAUSE_DESCR  FIRE_YEAR  DISCOVERY_DOY  FIRE_SIZE  \
# FOD_ID
# 1034469             NaN    Miscellaneous       1998            138       1.00
# 19104376            NaN   Debris Burning       1997            261       0.25
# 201779996      FRY FIRE   Debris Burning       2013            115       0.10
# 19106826            NaN   Debris Burning       1995            348       0.19
# 300116484  WESTERN FIRE            Arson       2014            242       0.40
#
#            LATITUDE  LONGITUDE STATE  CONTAINED DISCOVERY_MONTH  \
# FOD_ID
# 1034469    34.62810  -81.82470    SC      False               5
# 19104376   30.98440  -83.75630    GA       True               9
# 201779996  48.36531 -119.26689    WA       True               4
# 19106826   31.39550  -82.83810    GA       True              12
# 300116484  40.81730  -72.81690    NY       True               8
#
#            DISTANCE_CITY_1000000  DISTANCE_CITY_100000  DISTANCE_CITY_10000  \
# FOD_ID
# 1034469                 8.526956              1.008681             0.338856
# 19104376               11.542191              0.757382             0.198068
# 201779996               3.966366              1.549878             1.177989
# 19106826               11.493770              1.590253             0.113735
# 300116484               1.193952              0.503309             0.028905
#
#            DISTANCE_CITY_1000  APPROX_ELEVATION
# FOD_ID
# 1034469              0.165416             212.1
# 19104376             0.198068              86.3
# 201779996            0.697256             396.2
# 19106826             0.113735              78.3
# 300116484            0.028905              26.2

# %%
fires.to_csv("D:/wildfires/fires_merged.csv")

# %% [markdown]
# # Load weather data (todo)
